# %% [markdown]
# # Data Loading - Superstore
#
# This notebook loads the exported CSV files generated from the SQL Superstore project.
# The goal of this step is to verify data structure and completeness before any further transformations or analysis.
#
# #### The following datasets are loaded:
# - fact_sales.csv
# - dim_customer.csv
# - dim_product.csv
#
# #### This notebook focuses on:
# - Inspecting columns and structure
# - Checking for missing values
# - Checking the uniqueness of key columns

# %%
import pandas as pd

# %%
customers = pd.read_csv("../data/dim_customer.csv")
products = pd.read_csv("../data/dim_product.csv")
sales = pd.read_csv("../data/fact_sales.csv")

# %%
customers.shape
# Out:
# (793, 3)

# %%
products.shape
# Out:
# (1862, 4)

# %%
sales.shape
# Out:
# (9994, 16)

# %% [markdown]
# ### Data Quality Check
#
# Below section of this notebook:
# - reviews the columns and first rows of each table
# - counts missing values in all columns
# - checks for duplicates in each key column
#
# This is to ensure that the uploaded data is reliable and appropriate for further transformation and analysis.

# %%
customers.head(2)
# Out:
#   customer_id  customer_name    segment
# 0    JC-15775   John Castell   Consumer
# 1    EB-13840  Ellis Ballard  Corporate

# %%
products.head(2)
# Out:
#         product_id   category sub_category  \
# 0  FUR-BO-10000112  Furniture    Bookcases
# 1  FUR-BO-10000330  Furniture    Bookcases
#
#                                         product_name
# 0   Bush Birmingham Collection Bookcase, Dark Cherry
# 1  Sauder Camden County Barrister Bookcase, Plank...

# %%
sales.head(2)
# Out:
#    row_id        order_id order_date_day ship_date_day       ship_mode  \
# 0    9648  CA-2014-150518     2014-11-19    2014-11-24  Standard Class
# 1    2382  CA-2016-118052     2016-05-06    2016-05-10  Standard Class
#
#   customer_id        country      state         city  postal_code   region  \
# 0    MW-18220  United States  Minnesota  Coon Rapids        55433  Central
# 1    BE-11455  United States       Ohio       Lorain        44052     East
#
#         product_id    sales  quantity  discount   profit
# 0  OFF-ST-10000877  221.160         4       0.0  57.5016
# 1  FUR-FU-10004848   54.712         7       0.2  11.6263

# %%
customers.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# segment          0
# dtype: int64

# %%
products.isnull().sum()
# Out:
# product_id      0
# category        0
# sub_category    0
# product_name    0
# dtype: int64

# %%
sales.isnull().sum()
# Out:
# row_id            0
# order_id          0
# order_date_day    0
# ship_date_day     0
# ship_mode         0
# customer_id       0
# country           0
# state             0
# city              0
# postal_code       0
# region            0
# product_id        0
# sales             0
# quantity          0
# discount          0
# profit            0
# dtype: int64

# %%
customers["customer_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
products["product_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
sales["row_id"].duplicated().sum()
# Out:
# np.int64(0)
